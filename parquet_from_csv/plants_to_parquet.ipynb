# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os
import matplotlib.pyplot as plt
from numpy import int8, int16

src = '../finalCCRSdata/'

# %% [markdown]
# # this table likely should be split to a destruction table and the live table. sparse data. Won't be processing it unless needed

# %%
file_list = os.listdir(src)

# get a list of prefixes
# prefix_list = list(set([file.split('_')[0] for file in file_list if '_' in file and file.endswith('.csv')]))
prefix_list = ['Plant']


# make a dictionary of dataframes
for prefix in prefix_list:
    prefix_files = [file for file in file_list if file.startswith(
        prefix) and file.endswith('.csv')]
    df_list = [pd.read_csv(os.path.join(src, file)) for file in prefix_files]
    df_concat = pd.concat(
        df_list, keys=[(prefix, file) for file in prefix_files], ignore_index=True)
# Out:
# /tmp/ipykernel_98063/694664981.py:12: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(src, file)) for file in prefix_files]
# /tmp/ipykernel_98063/694664981.py:12: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(src, file)) for file in prefix_files]
# /tmp/ipykernel_98063/694664981.py:12: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(src, file)) for file in prefix_files]
# /tmp/ipykernel_98063/694664981.py:12: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(src, file)) for file in prefix_files]
# /tmp/ipykernel_98063/694664981.py:12: DtypeWarning: Columns (10,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(src, file)) for file in prefix_files]
# /tmp/ipykernel_98063/694664981.py:12: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(src, file)) for file in prefix_files]
# /tmp/ipykernel_98063/694664981.py:12: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(src, file)) for file in prefix_files]

# %%
df_concat.columns
# Out:
# Index(['PlantId', 'LicenseeId', 'AreaId', 'StrainId', 'PlantSource',
#        'PlantState', 'GrowthStage', 'HarvestCycle', 'MotherPlantId',
#        'PlantIdentifier', 'HarvestDate', 'IsMotherPlant', 'ExternalIdentifier',
#        'IsDeleted', 'CreatedBy', 'CreatedDate', 'UpdatedBy', 'UpdatedDate',
#        'PlantDestructionId', 'DestructionReason', 'DestructionMethod',
#        'DestructionDate'],
#       dtype='object')

# %%
df_concat = df_concat[['PlantId', 'LicenseeId', 'AreaId', 'StrainId', 'PlantSource',
                       'PlantState', 'GrowthStage', 'HarvestCycle', 'MotherPlantId',
                       'PlantIdentifier', 'HarvestDate', 'IsMotherPlant', 'ExternalIdentifier',
                       'IsDeleted', 
                       #'CreatedBy', 
                       'CreatedDate', 
                       # 'UpdatedBy', 'UpdatedDate',
                       'PlantDestructionId', 'DestructionReason', 'DestructionMethod',
                       'DestructionDate'
                       ]]
#del df_list
#del file_list
#del df_concat

# %%
df_concat
# Out:
#          PlantId  LicenseeId    AreaId  StrainId PlantSource PlantState  \
# 0        2929015       298.0    1119.0       1.0       Clone       Sold
# 1        2929163       298.0    1018.0       1.0       Clone       Sold
# 2        2928940       298.0  241859.0       1.0       Clone    Growing
# 3        2928953       298.0   81466.0       1.0       Clone    Growing
# 4        2928982       298.0  227565.0       1.0       Clone    Growing
# ...          ...         ...       ...       ...         ...        ...
# 8930995   153828      2311.0    4596.0       1.0       Clone  Harvested
# 8930996   153829      2311.0    4596.0       1.0       Clone  Harvested
# 8930997   153830      2311.0    4596.0       1.0       Clone  Harvested
# 8930998   153831      2311.0    4596.0       1.0       Clone  Harvested
# 8930999   153832      2311.0    4596.0       1.0       Clone  Harvested
#
#         GrowthStage  HarvestCycle  MotherPlantId    PlantIdentifier  \
# 0         Flowering           3.0       989934.0   GF41243000001329
# 1         Flowering           3.0       990320.0   GF41243000001581
# 2        Vegetative           3.0       989544.0   GF41243000001409
# 3        Vegetative           3.0       989544.0   GF41243000001416
# 4        Vegetative           3.0       989544.0   GF41243000001445
# ...             ...           ...            ...                ...
# 8930995   Flowering           3.0            NaN  WAJ424481.PLI2CVJ
# 8930996   Flowering           3.0            NaN  WAJ424481.PLI2CVK
# 8930997   Flowering           3.0            NaN  WAJ424481.PLI2CVL
# 8930998   Flowering           3.0            NaN  WAJ424481.PLI2CVM
# 8930999   Flowering           3.0            NaN  WAJ424481.PLI2CVN
#
#                  HarvestDate IsMotherPlant ExternalIdentifier  IsDeleted  \
# 0                        NaN         False   GF41243000001329      False
# 1                        NaN         False   GF41243000001581      False
# 2                        NaN         False   GF41243000001409      False
# 3                        NaN         False   GF41243000001416      False
# 4                        NaN         False   GF41243000001445      False
# ...                      ...           ...                ...        ...
# 8930995  2022-02-07 18:19:00         False  C1-10310001434639      False
# 8930996  2022-02-07 18:19:00         False  C1-10310001434640      False
# 8930997  2022-02-07 18:19:00         False  C1-10310001434641      False
# 8930998  2022-02-07 18:19:00         False  C1-10310001434642      False
# 8930999  2022-02-07 18:19:00         False  C1-10310001434643      False
#
#                  CreatedDate  PlantDestructionId DestructionReason  \
# 0        2022-02-03 00:00:00                 NaN               NaN
# 1        2022-02-03 00:00:00                 NaN               NaN
# 2        2022-02-03 00:00:00                 NaN               NaN
# 3        2022-02-03 00:00:00                 NaN               NaN
# 4        2022-02-03 00:00:00                 NaN               NaN
# ...                      ...                 ...               ...
# 8930995  2021-10-20 16:57:00                 NaN               NaN
# 8930996  2021-10-20 16:57:00                 NaN               NaN
# 8930997  2021-10-20 16:57:00                 NaN               NaN
# 8930998  2021-10-20 16:57:00                 NaN               NaN
# 8930999  2021-10-20 16:57:00                 NaN               NaN
#
#         DestructionMethod DestructionDate
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 8930995               NaN             NaN
# 8930996               NaN             NaN
# 8930997               NaN             NaN
# 8930998               NaN             NaN
# 8930999               NaN             NaN
#
# [8931000 rows x 19 columns]

# %%
df_concat.isna().sum()
# Out:
# PlantId                     0
# LicenseeId             782227
# AreaId                 782227
# StrainId               782227
# PlantSource            782227
# PlantState             782227
# GrowthStage            782227
# HarvestCycle           782227
# MotherPlantId         6387869
# PlantIdentifier        782356
# HarvestDate           4935368
# IsMotherPlant          782227
# ExternalIdentifier        125
# IsDeleted                   0
# CreatedDate                 0
# PlantDestructionId    8148773
# DestructionReason     8148773
# DestructionMethod     8148773
# DestructionDate       8148773
# dtype: int64

# %%
#df_concat['Name'] = df_concat['Name'].fillna('Unknown')

# %%
df_concat.loc[df_concat.duplicated()]

# not sure what to do for the duplicates in this table, it appears that there is no primary key in this table. may need to modify the relationships in postgres
# Out:
#          PlantId  LicenseeId   AreaId  StrainId PlantSource PlantState  \
# 1782227  5366779       592.0  20301.0       1.0       Clone    Growing
# 1782228  5366780       592.0  20301.0       1.0       Clone    Growing
# 1782229  5366781       592.0  20301.0       1.0       Clone    Growing
# 1782230  5366782       592.0  20301.0       1.0       Clone    Growing
# 1782231  5366783       592.0  20301.0       1.0       Clone    Growing
# ...          ...         ...      ...       ...         ...        ...
# 8930995   153828      2311.0   4596.0       1.0       Clone  Harvested
# 8930996   153829      2311.0   4596.0       1.0       Clone  Harvested
# 8930997   153830      2311.0   4596.0       1.0       Clone  Harvested
# 8930998   153831      2311.0   4596.0       1.0       Clone  Harvested
# 8930999   153832      2311.0   4596.0       1.0       Clone  Harvested
#
#         GrowthStage  HarvestCycle  MotherPlantId    PlantIdentifier  \
# 1782227  Vegetative           3.0            NaN   01G5EPZ0NWMSVSKX
# 1782228  Vegetative           3.0            NaN   01G5EPZ0P6EE8TC9
# 1782229  Vegetative           3.0            NaN   01G5EPZ0PAZBAH13
# 1782230  Vegetative           3.0            NaN   01G5EPZ0PF3QGH96
# 1782231  Vegetative           3.0            NaN   01G5EPZ0PKCYQN3P
# ...             ...           ...            ...                ...
# 8930995   Flowering           3.0            NaN  WAJ424481.PLI2CVJ
# 8930996   Flowering           3.0            NaN  WAJ424481.PLI2CVK
# 8930997   Flowering           3.0            NaN  WAJ424481.PLI2CVL
# 8930998   Flowering           3.0            NaN  WAJ424481.PLI2CVM
# 8930999   Flowering           3.0            NaN  WAJ424481.PLI2CVN
#
#                  HarvestDate IsMotherPlant ExternalIdentifier  IsDeleted  \
# 1782227                  NaN          True   01G5EPZ0NWMSVSKX      False
# 1782228                  NaN          True   01G5EPZ0P6EE8TC9      False
# 1782229                  NaN          True   01G5EPZ0PAZBAH13      False
# 1782230                  NaN          True   01G5EPZ0PF3QGH96      False
# 1782231                  NaN          True   01G5EPZ0PKCYQN3P      False
# ...                      ...           ...                ...        ...
# 8930995  2022-02-07 18:19:00         False  C1-10310001434639      False
# 8930996  2022-02-07 18:19:00         False  C1-10310001434640      False
# 8930997  2022-02-07 18:19:00         False  C1-10310001434641      False
# 8930998  2022-02-07 18:19:00         False  C1-10310001434642      False
# 8930999  2022-02-07 18:19:00         False  C1-10310001434643      False
#
#                  CreatedDate  PlantDestructionId DestructionReason  \
# 1782227  2022-06-22 00:00:00                 NaN               NaN
# 1782228  2022-06-22 00:00:00                 NaN               NaN
# 1782229  2022-06-22 00:00:00                 NaN               NaN
# 1782230  2022-06-22 00:00:00                 NaN               NaN
# 1782231  2022-06-22 00:00:00                 NaN               NaN
# ...                      ...                 ...               ...
# 8930995  2021-10-20 16:57:00                 NaN               NaN
# 8930996  2021-10-20 16:57:00                 NaN               NaN
# 8930997  2021-10-20 16:57:00                 NaN               NaN
# 8930998  2021-10-20 16:57:00                 NaN               NaN
# 8930999  2021-10-20 16:57:00                 NaN               NaN
#
#         DestructionMethod DestructionDate
# 1782227               NaN             NaN
# 1782228               NaN             NaN
# 1782229               NaN             NaN
# 1782230               NaN             NaN
# 1782231               NaN             NaN
# ...                   ...             ...
# 8930995               NaN             NaN
# 8930996               NaN             NaN
# 8930997               NaN             NaN
# 8930998               NaN             NaN
# 8930999               NaN             NaN
#
# [13075 rows x 19 columns]

# %%
df_concat.drop_duplicates()
# Out:
#          PlantId  LicenseeId    AreaId  StrainId PlantSource PlantState  \
# 0        2929015       298.0    1119.0       1.0       Clone       Sold
# 1        2929163       298.0    1018.0       1.0       Clone       Sold
# 2        2928940       298.0  241859.0       1.0       Clone    Growing
# 3        2928953       298.0   81466.0       1.0       Clone    Growing
# 4        2928982       298.0  227565.0       1.0       Clone    Growing
# ...          ...         ...       ...       ...         ...        ...
# 8927653  7375111      2311.0   22966.0       1.0       Clone  Destroyed
# 8927654  7375112      2311.0   22966.0       1.0       Clone  Destroyed
# 8927655  7375113      2311.0   22966.0       1.0       Clone  Destroyed
# 8927656  7375114      2311.0   22966.0       1.0       Clone  Destroyed
# 8927657  7375115      2311.0   22966.0       1.0       Clone  Destroyed
#
#         GrowthStage  HarvestCycle  MotherPlantId    PlantIdentifier  \
# 0         Flowering           3.0       989934.0   GF41243000001329
# 1         Flowering           3.0       990320.0   GF41243000001581
# 2        Vegetative           3.0       989544.0   GF41243000001409
# 3        Vegetative           3.0       989544.0   GF41243000001416
# 4        Vegetative           3.0       989544.0   GF41243000001445
# ...             ...           ...            ...                ...
# 8927653   Flowering           3.0            NaN  11790413901654847
# 8927654   Flowering           3.0            NaN  11790413901654905
# 8927655   Flowering           3.0            NaN  11790414166396441
# 8927656   Flowering           3.0            NaN  11790414128186179
# 8927657   Flowering           3.0            NaN  11790414128186377
#
#         HarvestDate IsMotherPlant ExternalIdentifier  IsDeleted  \
# 0               NaN         False   GF41243000001329      False
# 1               NaN         False   GF41243000001581      False
# 2               NaN         False   GF41243000001409      False
# 3               NaN         False   GF41243000001416      False
# 4               NaN         False   GF41243000001445      False
# ...             ...           ...                ...        ...
# 8927653         NaN         False  C1-10310001452848      False
# 8927654         NaN         False  C1-10310001452849      False
# 8927655         NaN         False  C1-10310001453093      False
# 8927656         NaN         False  C1-10310001453010      False
# 8927657         NaN         False  C1-10310001453012      False
#
#                  CreatedDate  PlantDestructionId DestructionReason  \
# 0        2022-02-03 00:00:00                 NaN               NaN
# 1        2022-02-03 00:00:00                 NaN               NaN
# 2        2022-02-03 00:00:00                 NaN               NaN
# 3        2022-02-03 00:00:00                 NaN               NaN
# 4        2022-02-03 00:00:00                 NaN               NaN
# ...                      ...                 ...               ...
# 8927653  2022-02-01 21:43:00                 NaN               NaN
# 8927654  2022-02-01 21:43:00                 NaN               NaN
# 8927655  2022-02-01 22:27:00                 NaN               NaN
# 8927656  2022-02-01 22:21:00                 NaN               NaN
# 8927657  2022-02-01 22:21:00                 NaN               NaN
#
#         DestructionMethod DestructionDate
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 8927653               NaN             NaN
# 8927654               NaN             NaN
# 8927655               NaN             NaN
# 8927656               NaN             NaN
# 8927657               NaN             NaN
#
# [8917925 rows x 19 columns]

# %%
df_concat.isna().sum()
# Out:
# PlantId                     0
# LicenseeId             782227
# AreaId                 782227
# StrainId               782227
# PlantSource            782227
# PlantState             782227
# GrowthStage            782227
# HarvestCycle           782227
# MotherPlantId         6387869
# PlantIdentifier        782356
# HarvestDate           4935368
# IsMotherPlant          782227
# ExternalIdentifier        125
# IsDeleted                   0
# CreatedDate                 0
# PlantDestructionId    8148773
# DestructionReason     8148773
# DestructionMethod     8148773
# DestructionDate       8148773
# dtype: int64

# %%
df_concat.loc[df_concat['AreaId'].isna()]
# Out:
#          PlantId  LicenseeId  AreaId  StrainId PlantSource PlantState  \
# 1000000     2006         NaN     NaN       NaN         NaN        NaN
# 1000001     2007         NaN     NaN       NaN         NaN        NaN
# 1000002     2008         NaN     NaN       NaN         NaN        NaN
# 1000003     2009         NaN     NaN       NaN         NaN        NaN
# 1000004     2010         NaN     NaN       NaN         NaN        NaN
# ...          ...         ...     ...       ...         ...        ...
# 1782222  8148614         NaN     NaN       NaN         NaN        NaN
# 1782223  8148714         NaN     NaN       NaN         NaN        NaN
# 1782224  8148715         NaN     NaN       NaN         NaN        NaN
# 1782225  8148716         NaN     NaN       NaN         NaN        NaN
# 1782226  8148720         NaN     NaN       NaN         NaN        NaN
#
#         GrowthStage  HarvestCycle  MotherPlantId PlantIdentifier HarvestDate  \
# 1000000         NaN           NaN            NaN             NaN         NaN
# 1000001         NaN           NaN            NaN             NaN         NaN
# 1000002         NaN           NaN            NaN             NaN         NaN
# 1000003         NaN           NaN            NaN             NaN         NaN
# 1000004         NaN           NaN            NaN             NaN         NaN
# ...             ...           ...            ...             ...         ...
# 1782222         NaN           NaN            NaN             NaN         NaN
# 1782223         NaN           NaN            NaN             NaN         NaN
# 1782224         NaN           NaN            NaN             NaN         NaN
# 1782225         NaN           NaN            NaN             NaN         NaN
# 1782226         NaN           NaN            NaN             NaN         NaN
#
#         IsMotherPlant ExternalIdentifier  IsDeleted          CreatedDate  \
# 1000000           NaN       DTWDP.266319      False  2022-04-14 00:00:00
# 1000001           NaN       DTWDP.266320      False  2022-04-14 00:00:00
# 1000002           NaN       DTWDP.265277      False  2022-03-15 00:00:00
# 1000003           NaN       DTWDP.265276      False  2022-03-15 00:00:00
# 1000004           NaN       DTWDP.262423      False  2021-12-27 00:00:00
# ...               ...                ...        ...                  ...
# 1782222           NaN            5650187      False  2022-11-14 00:00:00
# 1782223           NaN            5682415      False  2022-11-17 00:00:00
# 1782224           NaN            5682416      False  2022-11-17 00:00:00
# 1782225           NaN            5682417      False  2022-11-17 00:00:00
# 1782226           NaN            5682422      False  2022-11-17 00:00:00
#
#          PlantDestructionId DestructionReason DestructionMethod  \
# 1000000            276029.0         PlantDied           Compost
# 1000001            276030.0         PlantDied           Compost
# 1000002            211459.0             Other           Compost
# 1000003            211458.0             Other           Compost
# 1000004              6687.0             Other           Compost
# ...                     ...               ...               ...
# 1782222            782203.0         PlantDied             Other
# 1782223            782224.0         PlantDied             Other
# 1782224            782225.0         PlantDied             Other
# 1782225            782226.0         PlantDied             Other
# 1782226            782227.0         PlantDied             Other
#
#         DestructionDate
# 1000000      2022-04-14
# 1000001      2022-04-14
# 1000002      2022-03-15
# 1000003      2022-03-15
# 1000004      2021-12-27
# ...                 ...
# 1782222      2022-11-14
# 1782223      2022-11-17
# 1782224      2022-11-17
# 1782225      2022-11-17
# 1782226      2022-11-17
#
# [782227 rows x 19 columns]

# %%
df_concat = df_concat.astype({
    'StrainId' :        int,
    'StrainType' :     str,
    'Name' :           str,
}, errors='ignore')
df_concat['CreatedDate'] = pd.to_datetime(df_concat['CreatedDate'])

# %%
df_concat.dtypes
# Out:
# StrainId                int64
# StrainType             object
# Name                   object
# IsDeleted                bool
# CreatedDate    datetime64[ns]
# dtype: object

# %%
df_concat.to_parquet('strains.parquet', index=False)
